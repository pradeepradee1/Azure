# %%
# %sql
use catalog deltalake_catalog;

# %%
# %sql
create volume deltalake_catalog.default.raw;

# %%
# %fs
mkdirs /Volumes/deltalake_catalog/default/raw/ordershistory
# Out:
# True

# %%
# %sql
LIST '/Volumes/deltalake_catalog/default/raw/ordershistory'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modification_time</th></tr></thead><tbody><tr><td>/Volumes/deltalake_catalog/default/raw/ordershistory/orders1.csv</td><td>orders1.csv</td><td>224</td><td>1760618387000</td></tr></tbody></table></div>

# %%
# %fs
ls '/Volumes/deltalake_catalog/default/raw/ordershistory'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/deltalake_catalog/default/raw/ordershistory/orders1.csv</td><td>orders1.csv</td><td>224</td><td>1760618387000</td></tr></tbody></table></div>

# %%
# %sql
select * from CSV.`/Volumes/deltalake_catalog/default/raw/ordershistory`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th></tr></thead><tbody><tr><td>order_id</td><td>order_date</td><td>customer_id</td><td>order_status</td></tr><tr><td>1111111</td><td>2013-07-25 00:00:00.0</td><td>11599</td><td>CLOSED</td></tr><tr><td>1111111</td><td>2013-07-25 00:00:00.0</td><td>256</td><td>PENDING_PAYMENT</td></tr><tr><td>3333333</td><td>2013-07-25 00:00:00.0</td><td>12111</td><td>COMPLETE</td></tr><tr><td>4444444</td><td>2013-07-25 00:00:00.0</td><td>8827</td><td>CLOSED</td></tr></tbody></table></div>

# %%
# %sql
drop table if exists orders;

create table orders
as
select * from 
read_files(
  '/Volumes/deltalake_catalog/default/raw/ordershistory',
  format => 'csv'
)
limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_date</th><th>customer_id</th><th>order_status</th><th>order_amount</th><th>_rescued_data</th></tr></thead><tbody><tr><td>100000</td><td>2013-07-25T00:00:00.000Z</td><td>11599</td><td>CLOSED</td><td>10</td><td>null</td></tr><tr><td>200000</td><td>2013-07-25T00:00:00.000Z</td><td>256</td><td>PENDING_PAYMENT</td><td>20</td><td>null</td></tr><tr><td>300000</td><td>2013-07-25T00:00:00.000Z</td><td>12111</td><td>COMPLETE</td><td>30</td><td>null</td></tr><tr><td>400000</td><td>2013-07-25T00:00:00.000Z</td><td>8827</td><td>CLOSED</td><td>40</td><td>null</td></tr><tr><td>5555555</td><td>2013-07-25T00:00:00.000Z</td><td>11599</td><td>CLOSED</td><td>null</td><td>null</td></tr><tr><td>6666666</td><td>2013-07-25T00:00:00.000Z</td><td>256</td><td>PENDING_PAYMENT</td><td>null</td><td>null</td></tr><tr><td>7777777</td><td>2013-07-25T00:00:00.000Z</td><td>COMPLETE</td><td>COMPLETE</td><td>null</td><td>null</td></tr><tr><td>8888888</td><td>2013-07-25T00:00:00.000Z</td><td>8827</td><td>CLOSED</td><td>null</td><td>null</td></tr><tr><td>1111111</td><td>2013-07-25T00:00:00.000Z</td><td>11599</td><td>CLOSED</td><td>null</td><td>null</td></tr><tr><td>1111111</td><td>2013-07-25T00:00:00.000Z</td><td>256</td><td>PENDING_PAYMENT</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
describe formatted orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>order_id</td><td>int</td><td>null</td></tr><tr><td>order_date</td><td>timestamp</td><td>null</td></tr><tr><td>customer_id</td><td>string</td><td>null</td></tr><tr><td>order_status</td><td>string</td><td>null</td></tr><tr><td>order_amount</td><td>int</td><td>null</td></tr><tr><td>_rescued_data</td><td>string</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>order_id, customer_id, order_amount, order_status, order_date, _rescued_data</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>deltalake_catalog</td><td></td></tr><tr><td>Database</td><td>default</td><td></td></tr><tr><td>Table</td><td>orders</td><td></td></tr><tr><td>Created Time</td><td>Thu Oct 16 12:49:13 UTC 2025</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Statistics</td><td>1909 bytes, 10 rows</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Collation</td><td>UTF8_BINARY</td><td></td></tr><tr><td>Location</td><td>abfss://unitycatalog@ttmystorageaccount001.dfs.core.windows.net/catalog/__unitystorage/catalogs/758280e5-e8ae-48b0-840c-9f10d52cc821/tables/e6cb4d32-39aa-430f-b971-98a766387d47</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>sumit.trendytech03@outlook.com</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_azure_centralindia)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.enableDeletionVectors=true,delta.feature.appendOnly=supported,delta.feature.deletionVectors=supported,delta.feature.invariants=supported,delta.minReaderVersion=3,delta.minWriterVersion=7]</td><td></td></tr></tbody></table></div>

# %%
# %sql
drop table if exists orders;

create table orders
as
select * from 
read_files(
  '/Volumes/deltalake_catalog/default/raw/ordershistory',
  format => 'csv',
  schema => 'order_id BIGINT, order_date STRING, customer_id BIGINT, order_status STRING, _rescued_data STRING',
  header => true,
  mode => 'PERMISSIVE',
  columnNameofCorruptRecord => '_rescued_data'
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_date</th><th>customer_id</th><th>order_status</th><th>_rescued_data</th></tr></thead><tbody><tr><td>1111111</td><td>2013-07-25 00:00:00.0</td><td>11599</td><td>CLOSED</td><td>null</td></tr><tr><td>1111111</td><td>2013-07-25 00:00:00.0</td><td>256</td><td>PENDING_PAYMENT</td><td>null</td></tr><tr><td>3333333</td><td>2013-07-25 00:00:00.0</td><td>12111</td><td>COMPLETE</td><td>null</td></tr><tr><td>4444444</td><td>2013-07-25 00:00:00.0</td><td>8827</td><td>CLOSED</td><td>null</td></tr><tr><td>888888</td><td>2013-07-25 00:00:00.0</td><td>11599</td><td>CLOSED</td><td>null</td></tr><tr><td>999999</td><td>2013-07-25 00:00:00.0</td><td>256</td><td>PENDING_PAYMENT</td><td>null</td></tr><tr><td>3</td><td>2013-07-25 00:00:00.0</td><td>12111</td><td>CLOSED</td><td>null</td></tr><tr><td>4</td><td>2013-07-25 00:00:00.0</td><td>8827</td><td>PENDING_PAYMENT</td><td>null</td></tr><tr><td>100000</td><td>2013-07-25 00:00:00.0</td><td>11599</td><td>CLOSED</td><td>100000,2013-07-25 00:00:00.0,11599,CLOSED,10</td></tr><tr><td>200000</td><td>2013-07-25 00:00:00.0</td><td>256</td><td>PENDING_PAYMENT</td><td>200000,2013-07-25 00:00:00.0,256,PENDING_PAYMENT,20</td></tr><tr><td>300000</td><td>2013-07-25 00:00:00.0</td><td>12111</td><td>COMPLETE</td><td>300000,2013-07-25 00:00:00.0,12111,COMPLETE,30</td></tr><tr><td>400000</td><td>2013-07-25 00:00:00.0</td><td>8827</td><td>CLOSED</td><td>400000,2013-07-25 00:00:00.0,8827,CLOSED,40</td></tr><tr><td>5555555</td><td>2013-07-25 00:00:00.0</td><td>11599</td><td>CLOSED</td><td>null</td></tr><tr><td>6666666</td><td>2013-07-25 00:00:00.0</td><td>256</td><td>PENDING_PAYMENT</td><td>null</td></tr><tr><td>7777777</td><td>2013-07-25 00:00:00.0</td><td>null</td><td>COMPLETE</td><td>7777777,2013-07-25 00:00:00.0,COMPLETE,COMPLETE</td></tr><tr><td>8888888</td><td>2013-07-25 00:00:00.0</td><td>8827</td><td>CLOSED</td><td>null</td></tr></tbody></table></div>

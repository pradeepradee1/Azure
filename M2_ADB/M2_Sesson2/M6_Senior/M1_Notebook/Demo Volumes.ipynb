# %%
# %sql
create volume deltalake_catalog.default.managed_vol;

# %%
# %fs
mkdirs /Volumes/deltalake_catalog/default/managed_vol/emp
# Out:
# True

# %%
# %sql
select * from 
CSV.`/Volumes/deltalake_catalog/default/managed_vol/emp`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th></tr></thead><tbody><tr><td>id</td><td>name</td><td>department</td><td>salary</td></tr><tr><td>1</td><td>John Doe</td><td>Engineering</td><td>120000</td></tr><tr><td>2</td><td>Jane Smith</td><td>Marketing</td><td>95000</td></tr><tr><td>3</td><td>Bob Johnson</td><td>Sales</td><td>105000</td></tr><tr><td>4</td><td>Alice Williams</td><td>Finance</td><td>98000</td></tr><tr><td>5</td><td>Charlie Brown</td><td>Engineering</td><td>125000</td></tr></tbody></table></div>

# %%
df = spark.read.format("csv").option("header", True).load("/Volumes/deltalake_catalog/default/managed_vol/emp")

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>department</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>John Doe</td><td>Engineering</td><td>120000</td></tr><tr><td>2</td><td>Jane Smith</td><td>Marketing</td><td>95000</td></tr><tr><td>3</td><td>Bob Johnson</td><td>Sales</td><td>105000</td></tr><tr><td>4</td><td>Alice Williams</td><td>Finance</td><td>98000</td></tr><tr><td>5</td><td>Charlie Brown</td><td>Engineering</td><td>125000</td></tr></tbody></table></div>

# %%
# %sql
drop volume deltalake_catalog.default.managed_vol;

# %%
# %sql
create volume deltalake_catalog.default.managed_vol;

# %%
df = spark.read.format("csv").option("header", True).load("/Volumes/deltalake_catalog/default/managed_vol/emp")

# %%
# %sql
create external volume deltalake_catalog.default.external_vol
LOCATION 'abfss://externaldata@ttmystorageaccount001.dfs.core.windows.net/ext_volume'

# %%
# %fs
mkdirs /Volumes/deltalake_catalog/default/external_vol/emp
# Out:
# True

# %%
# %sql
select * from CSV.`/Volumes/deltalake_catalog/default/external_vol/emp`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th></tr></thead><tbody><tr><td>id</td><td>name</td><td>department</td><td>salary</td></tr><tr><td>1</td><td>John Doe</td><td>Engineering</td><td>120000</td></tr><tr><td>2</td><td>Jane Smith</td><td>Marketing</td><td>95000</td></tr><tr><td>3</td><td>Bob Johnson</td><td>Sales</td><td>105000</td></tr><tr><td>4</td><td>Alice Williams</td><td>Finance</td><td>98000</td></tr><tr><td>5</td><td>Charlie Brown</td><td>Engineering</td><td>125000</td></tr></tbody></table></div>

# %%
# %sql
drop volume deltalake_catalog.default.external_vol;

# %%
# %sql
create external volume deltalake_catalog.default.external_vol
LOCATION 'abfss://externaldata@ttmystorageaccount001.dfs.core.windows.net/ext_volume'

# %%
# %sql
select * from CSV.`/Volumes/deltalake_catalog/default/external_vol/emp`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th></tr></thead><tbody><tr><td>id</td><td>name</td><td>department</td><td>salary</td></tr><tr><td>1</td><td>John Doe</td><td>Engineering</td><td>120000</td></tr><tr><td>2</td><td>Jane Smith</td><td>Marketing</td><td>95000</td></tr><tr><td>3</td><td>Bob Johnson</td><td>Sales</td><td>105000</td></tr><tr><td>4</td><td>Alice Williams</td><td>Finance</td><td>98000</td></tr><tr><td>5</td><td>Charlie Brown</td><td>Engineering</td><td>125000</td></tr></tbody></table></div>

# %%
df = spark.read.format("csv").option("header", True).load("/Volumes/deltalake_catalog/default/external_vol/emp")

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>department</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>John Doe</td><td>Engineering</td><td>120000</td></tr><tr><td>2</td><td>Jane Smith</td><td>Marketing</td><td>95000</td></tr><tr><td>3</td><td>Bob Johnson</td><td>Sales</td><td>105000</td></tr><tr><td>4</td><td>Alice Williams</td><td>Finance</td><td>98000</td></tr><tr><td>5</td><td>Charlie Brown</td><td>Engineering</td><td>125000</td></tr></tbody></table></div>

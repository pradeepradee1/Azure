# %%
# %sql
use catalog deltalake_catalog;

# %%
# %sql
drop table if exists orders;

# %%
# %sql
create table orders(
  order_id int,
  order_date string,
  customer_id int,
  order_status string,
  _file_name string,
  _load_date timestamp
) using delta;

# %%
# %sql
copy into deltalake_catalog.default.orders
from (select cast(order_id as int) as order_id, 
order_date, 
cast(customer_id as int) as customer_id, 
order_status,
_metadata.file_name as _file_name,
current_timestamp() as _load_date 

from "/Volumes/deltalake_catalog/default/raw/ordershistory") 
FILEFORMAT = CSV
FORMAT_OPTIONS(
  'header' = 'true'
  ) ;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th><th>num_skipped_corrupt_files</th></tr></thead><tbody><tr><td>8</td><td>8</td><td>0</td></tr></tbody></table></div>

# %%
# %sql
select * from deltalake_catalog.default.orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_date</th><th>customer_id</th><th>order_status</th><th>_file_name</th><th>_load_date</th></tr></thead><tbody><tr><td>1111111</td><td>2013-07-25 00:00:00.0</td><td>11599</td><td>CLOSED</td><td>orders1.csv</td><td>2025-10-16T17:53:43.198Z</td></tr><tr><td>1111111</td><td>2013-07-25 00:00:00.0</td><td>256</td><td>PENDING_PAYMENT</td><td>orders1.csv</td><td>2025-10-16T17:53:43.198Z</td></tr><tr><td>3333333</td><td>2013-07-25 00:00:00.0</td><td>12111</td><td>COMPLETE</td><td>orders1.csv</td><td>2025-10-16T17:53:43.198Z</td></tr><tr><td>4444444</td><td>2013-07-25 00:00:00.0</td><td>8827</td><td>CLOSED</td><td>orders1.csv</td><td>2025-10-16T17:53:43.198Z</td></tr><tr><td>888888</td><td>2013-07-25 00:00:00.0</td><td>11599</td><td>CLOSED</td><td>orders2.csv</td><td>2025-10-16T17:53:43.198Z</td></tr><tr><td>999999</td><td>2013-07-25 00:00:00.0</td><td>256</td><td>PENDING_PAYMENT</td><td>orders2.csv</td><td>2025-10-16T17:53:43.198Z</td></tr><tr><td>3</td><td>2013-07-25 00:00:00.0</td><td>12111</td><td>CLOSED</td><td>orders2.csv</td><td>2025-10-16T17:53:43.198Z</td></tr><tr><td>4</td><td>2013-07-25 00:00:00.0</td><td>8827</td><td>PENDING_PAYMENT</td><td>orders2.csv</td><td>2025-10-16T17:53:43.198Z</td></tr></tbody></table></div>

# %%
# %sql
describe formatted deltalake_catalog.default.orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>order_id</td><td>int</td><td>null</td></tr><tr><td>order_date</td><td>string</td><td>null</td></tr><tr><td>customer_id</td><td>int</td><td>null</td></tr><tr><td>order_status</td><td>string</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>order_id, order_date, customer_id, order_status</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>deltalake_catalog</td><td></td></tr><tr><td>Database</td><td>default</td><td></td></tr><tr><td>Table</td><td>orders</td><td></td></tr><tr><td>Created Time</td><td>Thu Oct 16 17:42:50 UTC 2025</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Statistics</td><td>1469 bytes, 4 rows</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Collation</td><td>UTF8_BINARY</td><td></td></tr><tr><td>Location</td><td>abfss://unitycatalog@ttmystorageaccount001.dfs.core.windows.net/catalog/__unitystorage/catalogs/758280e5-e8ae-48b0-840c-9f10d52cc821/tables/a0450290-dbbd-4461-81e4-645aedb674ff</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>sumit.trendytech03@outlook.com</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_azure_centralindia)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.enableDeletionVectors=true,delta.enableRowTracking=true,delta.feature.appendOnly=supported,delta.feature.deletionVectors=supported,delta.feature.domainMetadata=supported,delta.feature.invariants=supported,delta.feature.rowTracking=supported,delta.minReaderVersion=3,delta.minWriterVersion=7,delta.rowTracking.materializedRowCommitVersionColumnName=_row-commit-version-col-9d2f1f68-49a1-42b2-9024-123c45098527,delta.rowTracking.materializedRowIdColumnName=_row-id-col-9397dc77-fa04-4d15-b6cd-a318221192d6]</td><td></td></tr></tbody></table></div>

# %%
# %sql
describe history deltalake_catalog.default.orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>1</td><td>2025-10-16T17:53:43.000Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>COPY INTO</td><td>Map(statsOnLoad -> true)</td><td>null</td><td>List(1905767248284052)</td><td>1016-164818-xu0t8pui-v2n</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 8, numOutputBytes -> 2047, numSkippedCorruptFiles -> 0)</td><td>null</td><td>Databricks-Runtime/17.2.x-photon-scala2.13</td></tr><tr><td>0</td><td>2025-10-16T17:52:26.000Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>CREATE TABLE</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {"delta.enableDeletionVectors":"true","delta.enableRowTracking":"true","delta.rowTracking.materializedRowIdColumnName":"_row-id-col-c9d6fb2a-1101-4987-8dcd-cd4083c15f72","delta.rowTracking.materializedRowCommitVersionColumnName":"_row-commit-version-col-fd8602b0-8db4-4dd9-90bd-cc9a6e6c2bc2"}, statsOnLoad -> false)</td><td>null</td><td>List(1905767248284052)</td><td>1016-164818-xu0t8pui-v2n</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/17.2.x-photon-scala2.13</td></tr></tbody></table></div>

# %%
# %sql
use catalog deltalake_catalog;

# %%
landing_zone = "/Volumes/deltalake_catalog/default/raw"
orders_data = landing_zone + "/ordershistory"
checkpoint_path = landing_zone + "/orders_checkpoint"

# %%
ordersdf = (spark.readStream 
.format("cloudFiles") 
.option("cloudFiles.format", "csv") 
.option("cloudFiles.inferSchema", "true") 
.option("cloudFiles.inferColumnTypes", "true") 
.option("cloudFiles.schemaLocation", checkpoint_path) 
.option("cloudFiles.schemaEvolutionMode", "addNewColumns")
.load(orders_data))

# %%
# %sql
drop table if exists deltalake_catalog.default.ordersdelta;

# %%
ordersdf.writeStream \
.format("delta") \
.option("checkpointLocation", checkpoint_path) \
.option("mergeSchema", True) \
.outputMode("append") \
.trigger(availableNow=True) \
.toTable("deltalake_catalog.default.ordersdelta")

# %%
# %sql
select * from deltalake_catalog.default.ordersdelta;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>order_date</th><th>customer_id</th><th>order_status</th><th>_rescued_data</th><th>order_amount</th></tr></thead><tbody><tr><td>5555555</td><td>2013-07-25T00:00:00.000Z</td><td>11599</td><td>CLOSED</td><td>null</td><td>null</td></tr><tr><td>6666666</td><td>2013-07-25T00:00:00.000Z</td><td>256</td><td>PENDING_PAYMENT</td><td>null</td><td>null</td></tr><tr><td>7777777</td><td>2013-07-25T00:00:00.000Z</td><td>null</td><td>COMPLETE</td><td>{"customer_id":"COMPLETE","_file_path":"/Volumes/deltalake_catalog/default/raw/ordershistory/orders4.csv"}</td><td>null</td></tr><tr><td>8888888</td><td>2013-07-25T00:00:00.000Z</td><td>8827</td><td>CLOSED</td><td>null</td><td>null</td></tr><tr><td>100000</td><td>2013-07-25T00:00:00.000Z</td><td>11599</td><td>CLOSED</td><td>null</td><td>10</td></tr><tr><td>200000</td><td>2013-07-25T00:00:00.000Z</td><td>256</td><td>PENDING_PAYMENT</td><td>null</td><td>20</td></tr><tr><td>300000</td><td>2013-07-25T00:00:00.000Z</td><td>12111</td><td>COMPLETE</td><td>null</td><td>30</td></tr><tr><td>400000</td><td>2013-07-25T00:00:00.000Z</td><td>8827</td><td>CLOSED</td><td>null</td><td>40</td></tr><tr><td>1111111</td><td>2013-07-25T00:00:00.000Z</td><td>11599</td><td>CLOSED</td><td>null</td><td>null</td></tr><tr><td>1111111</td><td>2013-07-25T00:00:00.000Z</td><td>256</td><td>PENDING_PAYMENT</td><td>null</td><td>null</td></tr><tr><td>3333333</td><td>2013-07-25T00:00:00.000Z</td><td>12111</td><td>COMPLETE</td><td>null</td><td>null</td></tr><tr><td>4444444</td><td>2013-07-25T00:00:00.000Z</td><td>8827</td><td>CLOSED</td><td>null</td><td>null</td></tr><tr><td>888888</td><td>2013-07-25T00:00:00.000Z</td><td>11599</td><td>CLOSED</td><td>null</td><td>null</td></tr><tr><td>999999</td><td>2013-07-25T00:00:00.000Z</td><td>256</td><td>PENDING_PAYMENT</td><td>null</td><td>null</td></tr><tr><td>3</td><td>2013-07-25T00:00:00.000Z</td><td>12111</td><td>CLOSED</td><td>null</td><td>null</td></tr><tr><td>4</td><td>2013-07-25T00:00:00.000Z</td><td>8827</td><td>PENDING_PAYMENT</td><td>null</td><td>null</td></tr></tbody></table></div>

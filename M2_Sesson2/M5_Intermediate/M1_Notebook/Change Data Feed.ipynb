# %%
# %sql
use catalog deltalake_catalog;

# %%
# %sql
DROP TABLE IF EXISTS demo;

CREATE TABLE demo (
  id INT,
  name STRING,
  amount DOUBLE
);

# %%
# %sql
INSERT INTO demo VALUES (1, 'alice', 100.0), (2, 'bob', 200.0), (3, 'carol', 300.0);
SELECT * FROM demo;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>amount</th></tr></thead><tbody><tr><td>1</td><td>alice</td><td>100.0</td></tr><tr><td>2</td><td>bob</td><td>200.0</td></tr><tr><td>3</td><td>carol</td><td>300.0</td></tr></tbody></table></div>

# %%
# %sql
describe history demo;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>1</td><td>2025-09-12T20:36:06.000Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> true, partitionBy -> [])</td><td>null</td><td>List(1933854126676085)</td><td>0912-174551-ecph2b10-v2n</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 3, numOutputBytes -> 1022)</td><td>null</td><td>Databricks-Runtime/17.1.x-photon-scala2.13</td></tr><tr><td>0</td><td>2025-09-12T20:35:40.000Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>CREATE TABLE</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {"collation":"UTF8_BINARY","delta.enableDeletionVectors":"true"}, statsOnLoad -> false)</td><td>null</td><td>List(1933854126676085)</td><td>0912-174551-ecph2b10-v2n</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/17.1.x-photon-scala2.13</td></tr></tbody></table></div>

# %%
# %sql
ALTER TABLE demo SET TBLPROPERTIES (delta.enableChangeDataFeed = true);

# %%
# %sql
describe history demo;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>2</td><td>2025-09-12T20:37:33.000Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>SET TBLPROPERTIES</td><td>Map(properties -> {"delta.enableChangeDataFeed":"true"})</td><td>null</td><td>List(1933854126676085)</td><td>0912-174551-ecph2b10-v2n</td><td>1</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/17.1.x-photon-scala2.13</td></tr><tr><td>1</td><td>2025-09-12T20:36:06.000Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> true, partitionBy -> [])</td><td>null</td><td>List(1933854126676085)</td><td>0912-174551-ecph2b10-v2n</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 3, numOutputBytes -> 1022)</td><td>null</td><td>Databricks-Runtime/17.1.x-photon-scala2.13</td></tr><tr><td>0</td><td>2025-09-12T20:35:40.000Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>CREATE TABLE</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> true, properties -> {"collation":"UTF8_BINARY","delta.enableDeletionVectors":"true"}, statsOnLoad -> false)</td><td>null</td><td>List(1933854126676085)</td><td>0912-174551-ecph2b10-v2n</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/17.1.x-photon-scala2.13</td></tr></tbody></table></div>

# %%
# %sql
-- Update
UPDATE demo SET amount = amount * 1.1 WHERE id = 2;

-- Insert additional
INSERT INTO demo VALUES (4, 'dan', 400.0);

-- Delete
DELETE FROM demo WHERE id = 1;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
describe history demo;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>7</td><td>2025-09-12T20:38:53.000Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], auto -> true, clusterBy -> [], zOrderBy -> [], batchId -> 0)</td><td>null</td><td>List(1933854126676085)</td><td>0912-174551-ecph2b10-v2n</td><td>6</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 2, numRemovedBytes -> 2011, p25FileSize -> 1033, numDeletionVectorsRemoved -> 1, minFileSize -> 1033, numAddedFiles -> 1, maxFileSize -> 1033, p75FileSize -> 1033, p50FileSize -> 1033, numAddedBytes -> 1033)</td><td>null</td><td>Databricks-Runtime/17.1.x-photon-scala2.13</td></tr><tr><td>6</td><td>2025-09-12T20:38:51.000Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>DELETE</td><td>Map(predicate -> ["(id#29133 = 1)"])</td><td>null</td><td>List(1933854126676085)</td><td>0912-174551-ecph2b10-v2n</td><td>5</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 717, numDeletionVectorsUpdated -> 0, numDeletedRows -> 1, scanTimeMs -> 534, numAddedFiles -> 0, numAddedBytes -> 0, rewriteTimeMs -> 183)</td><td>null</td><td>Databricks-Runtime/17.1.x-photon-scala2.13</td></tr><tr><td>5</td><td>2025-09-12T20:38:50.001Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], auto -> true, clusterBy -> [], zOrderBy -> [], batchId -> 0)</td><td>null</td><td>List(1933854126676085)</td><td>0912-174551-ecph2b10-v2n</td><td>3</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 2, numRemovedBytes -> 2185, p25FileSize -> 1039, numDeletionVectorsRemoved -> 1, conflictDetectionTimeMs -> 14, minFileSize -> 1039, numAddedFiles -> 1, maxFileSize -> 1039, p75FileSize -> 1039, p50FileSize -> 1039, numAddedBytes -> 1039)</td><td>null</td><td>Databricks-Runtime/17.1.x-photon-scala2.13</td></tr><tr><td>4</td><td>2025-09-12T20:38:50.000Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> true, partitionBy -> [])</td><td>null</td><td>List(1933854126676085)</td><td>0912-174551-ecph2b10-v2n</td><td>3</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 1, numOutputBytes -> 972)</td><td>null</td><td>Databricks-Runtime/17.1.x-photon-scala2.13</td></tr><tr><td>3</td><td>2025-09-12T20:38:49.000Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>UPDATE</td><td>Map(predicate -> ["(id#28600 = 2)"])</td><td>null</td><td>List(1933854126676085)</td><td>0912-174551-ecph2b10-v2n</td><td>2</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 1, executionTimeMs -> 1407, numDeletionVectorsUpdated -> 0, scanTimeMs -> 575, numAddedFiles -> 1, numUpdatedRows -> 1, numAddedBytes -> 1163, rewriteTimeMs -> 831)</td><td>null</td><td>Databricks-Runtime/17.1.x-photon-scala2.13</td></tr><tr><td>2</td><td>2025-09-12T20:37:33.000Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>SET TBLPROPERTIES</td><td>Map(properties -> {"delta.enableChangeDataFeed":"true"})</td><td>null</td><td>List(1933854126676085)</td><td>0912-174551-ecph2b10-v2n</td><td>1</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/17.1.x-photon-scala2.13</td ...

# %%
# %sql
SELECT * FROM table_changes('demo', 2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>amount</th><th>_change_type</th><th>_commit_version</th><th>_commit_timestamp</th></tr></thead><tbody><tr><td>2</td><td>bob</td><td>200.0</td><td>update_preimage</td><td>3</td><td>2025-09-12T20:38:49.000Z</td></tr><tr><td>2</td><td>bob</td><td>220.00000000000003</td><td>update_postimage</td><td>3</td><td>2025-09-12T20:38:49.000Z</td></tr><tr><td>4</td><td>dan</td><td>400.0</td><td>insert</td><td>4</td><td>2025-09-12T20:38:50.000Z</td></tr><tr><td>1</td><td>alice</td><td>100.0</td><td>delete</td><td>6</td><td>2025-09-12T20:38:51.000Z</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM table_changes('demo', 2, 4)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>amount</th><th>_change_type</th><th>_commit_version</th><th>_commit_timestamp</th></tr></thead><tbody><tr><td>2</td><td>bob</td><td>200.0</td><td>update_preimage</td><td>3</td><td>2025-09-12T20:38:49.000Z</td></tr><tr><td>2</td><td>bob</td><td>220.00000000000003</td><td>update_postimage</td><td>3</td><td>2025-09-12T20:38:49.000Z</td></tr><tr><td>4</td><td>dan</td><td>400.0</td><td>insert</td><td>4</td><td>2025-09-12T20:38:50.000Z</td></tr></tbody></table></div>

# %%
# %sql
DELETE FROM demo WHERE id = 2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM table_changes('demo', 2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>amount</th><th>_change_type</th><th>_commit_version</th><th>_commit_timestamp</th></tr></thead><tbody><tr><td>2</td><td>bob</td><td>200.0</td><td>update_preimage</td><td>3</td><td>2025-09-12T20:38:49.000Z</td></tr><tr><td>2</td><td>bob</td><td>220.00000000000003</td><td>update_postimage</td><td>3</td><td>2025-09-12T20:38:49.000Z</td></tr><tr><td>4</td><td>dan</td><td>400.0</td><td>insert</td><td>4</td><td>2025-09-12T20:38:50.000Z</td></tr><tr><td>1</td><td>alice</td><td>100.0</td><td>delete</td><td>6</td><td>2025-09-12T20:38:51.000Z</td></tr><tr><td>2</td><td>bob</td><td>220.00000000000003</td><td>delete</td><td>8</td><td>2025-09-12T20:43:17.000Z</td></tr></tbody></table></div>

# %%
# %sql
DROP TABLE IF EXISTS demo_deleted_data_batch;

CREATE TABLE IF NOT EXISTS demo_deleted_data_batch (
  id INT,
  name STRING,
  amount DOUBLE,
  _commit_type STRING,
  _commit_version LONG,
  _commit_timestamp TIMESTAMP
)
USING delta;

# %%
# %sql
INSERT INTO demo_deleted_data_batch
SELECT id, name, amount, _change_type, _commit_version, _commit_timestamp 
FROM table_changes('demo', 2)
where _change_type = 'delete';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
select * from demo_deleted_data_batch;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>amount</th><th>_commit_type</th><th>_commit_version</th><th>_commit_timestamp</th></tr></thead><tbody><tr><td>1</td><td>alice</td><td>100.0</td><td>delete</td><td>6</td><td>2025-09-12T20:38:51.000Z</td></tr><tr><td>1</td><td>alice</td><td>100.0</td><td>delete</td><td>6</td><td>2025-09-12T20:38:51.000Z</td></tr><tr><td>1</td><td>alice</td><td>100.0</td><td>delete</td><td>6</td><td>2025-09-12T20:38:51.000Z</td></tr><tr><td>3</td><td>carol</td><td>300.0</td><td>delete</td><td>10</td><td>2025-09-12T20:56:34.000Z</td></tr><tr><td>3</td><td>carol</td><td>300.0</td><td>delete</td><td>10</td><td>2025-09-12T20:56:34.000Z</td></tr><tr><td>2</td><td>bob</td><td>220.00000000000003</td><td>delete</td><td>8</td><td>2025-09-12T20:43:17.000Z</td></tr><tr><td>2</td><td>bob</td><td>220.00000000000003</td><td>delete</td><td>8</td><td>2025-09-12T20:43:17.000Z</td></tr><tr><td>2</td><td>bob</td><td>220.00000000000003</td><td>delete</td><td>8</td><td>2025-09-12T20:43:17.000Z</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import col

(spark.readStream.format("delta")
    .option("readChangeFeed", "true")
    .option("startingVersion", 2)  
    .table("demo")
    .filter(col("_change_type") == "delete")  
    .select("id", "name")
    .writeStream
    .outputMode("append")
    .option("checkpointLocation", "/Volumes/deltalake_catalog/default/delta_volume1/checkpoint/") 
    .trigger(availableNow=True) 
    .table("demo_deleted_data_streaming"))

# %%
# %sql
select * from demo_deleted_data_streaming;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th></tr></thead><tbody><tr><td>3</td><td>carol</td></tr><tr><td>1</td><td>alice</td></tr><tr><td>2</td><td>bob</td></tr></tbody></table></div>

# %%
# %sql
DELETE FROM demo WHERE id = 3;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import col

(spark.readStream.format("delta")
    .option("readChangeFeed", "true")
    .option("startingVersion", 2)  
    .table("demo")
    .filter(col("_change_type") == "delete")  
    .select("id", "name")
    .writeStream
    .outputMode("append")
    .option("checkpointLocation", "/Volumes/deltalake_catalog/default/delta_volume1/checkpoint1/") 
    .trigger(processingTime="2 seconds") 
    .table("demo_deleted_data_streaming_auto"))

# %%
# %sql
select * from demo_deleted_data_streaming_auto;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th></tr></thead><tbody><tr><td>3</td><td>carol</td></tr><tr><td>6</td><td>Frank</td></tr><tr><td>7</td><td>Grace</td></tr><tr><td>1</td><td>alice</td></tr><tr><td>2</td><td>bob</td></tr></tbody></table></div>

# %%
# %sql
INSERT INTO demo VALUES
  (6, 'Frank', 600.0),
  (7, 'Grace', 700.0),
  (8, 'Heidi', 800.0),
  (9, 'Ivan', 900.0),
  (10, 'Judy', 1000.0);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

# %%
# %sql
DELETE FROM demo WHERE id = 7;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
use catalog deltalake_catalog;

# %%
# %sql
DROP TABLE IF EXISTS orders_managed;


CREATE OR REPLACE TABLE orders_managed (
order_id BIGINT,
sku STRING,
product_name STRING,
product_category STRING,
qty INT,
unit_price DECIMAL(10,2)
) TBLPROPERTIES ( 'delta.columnMapping.mode' = 'name',
'delta.enableIcebergCompatV2' = 'true',
'delta.universalFormat.enabledFormats' = 'iceberg'
)

# %%
# %sql
INSERT INTO orders_managed VALUES
  (1, 'SKU-1001', 'Wireless Mouse', 'Electronics', 2, 799.00),
  (2, 'SKU-2001', 'Yoga Mat', 'Fitness', 1, 1199.00),
  (3, 'SKU-3001', 'Notebook A5', 'Stationery', 5, 49.50),
  (4, 'SKU-4001', 'Coffee Mug', 'Kitchen', 3, 299.00),
  (5, 'SKU-5001', 'LED Bulb', 'Electronics', 4, 149.99);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

# %%
# %sql
describe formatted orders_managed
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>order_id</td><td>bigint</td><td>null</td></tr><tr><td>sku</td><td>string</td><td>null</td></tr><tr><td>product_name</td><td>string</td><td>null</td></tr><tr><td>product_category</td><td>string</td><td>null</td></tr><tr><td>qty</td><td>int</td><td>null</td></tr><tr><td>unit_price</td><td>decimal(10,2)</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>col-08cdd8c7-517d-4461-98da-42b5f6121bcf, col-be236c60-d7b6-42c6-b5e9-132a53c07728, col-2fb21fbc-8b8c-44cb-b2f8-835a64cd36ba, col-588d447a-dafa-4c14-87e0-85b57d418039, col-d6e7e938-a7f8-4f8e-9daf-d7645322f16e, col-3ce585e6-a051-4280-9123-c9748d30f6d3</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Uniform Iceberg</td><td></td><td></td></tr><tr><td>Metadata location</td><td>abfss://unitycatalog@ttmystorageaccount001.dfs.core.windows.net/catalog/__unitystorage/catalogs/758280e5-e8ae-48b0-840c-9f10d52cc821/tables/f3a0379a-f4d7-4c10-aa1b-95b7cb06bc9e/metadata/00001-fd29e04e-a956-4478-a75c-2bbd602c68cf.metadata.json</td><td></td></tr><tr><td>Converted delta version</td><td>1</td><td></td></tr><tr><td>Converted delta timestamp</td><td>2025-09-26T10:09:34.970014691Z</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>deltalake_catalog</td><td></td></tr><tr><td>Database</td><td>default</td><td></td></tr><tr><td>Table</td><td>orders_managed</td><td></td></tr><tr><td>Created Time</td><td>Fri Sep 26 10:08:51 UTC 2025</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Statistics</td><td>3666 bytes, 5 rows</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Collation</td><td>UTF8_BINARY</td><td></td></tr><tr><td>Location</td><td>abfss://unitycatalog@ttmystorageaccount001.dfs.core.windows.net/catalog/__unitystorage/catalogs/758280e5-e8ae-48b0-840c-9f10d52cc821/tables/f3a0379a-f4d7-4c10-aa1b-95b7cb06bc9e</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>sumit.trendytech03@outlook.com</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_azure_centralindia)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.columnMapping.maxColumnId=6,delta.columnMapping.mode=name,delta.enableIcebergCompatV2=true,delta.feature.appendOnly=supported,delta.feature.columnMapping=supported,delta.feature.icebergCompatV2=supported,delta.feature.invariants=supported,delta.minReaderVersion=2,delta.minWriterVersion=7,delta.universalFormat.enabledFormats=iceberg]</td><td></td></tr></tbody></table></div>

# %%
# %sql
show tblproperties orders_managed;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th></tr></thead><tbody><tr><td>delta.columnMapping.maxColumnId</td><td>6</td></tr><tr><td>delta.columnMapping.mode</td><td>name</td></tr><tr><td>delta.enableIcebergCompatV2</td><td>true</td></tr><tr><td>delta.feature.appendOnly</td><td>supported</td></tr><tr><td>delta.feature.columnMapping</td><td>supported</td></tr><tr><td>delta.feature.icebergCompatV2</td><td>supported</td></tr><tr><td>delta.feature.invariants</td><td>supported</td></tr><tr><td>delta.minReaderVersion</td><td>2</td></tr><tr><td>delta.minWriterVersion</td><td>7</td></tr><tr><td>delta.universalFormat.enabledFormats</td><td>iceberg</td></tr></tbody></table></div>

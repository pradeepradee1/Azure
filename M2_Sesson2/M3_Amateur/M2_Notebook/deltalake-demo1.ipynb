# %%
# %sql
CREATE OR REPLACE TABLE orders_managed (
order_id BIGINT,
sku STRING,
product_name STRING,
product_category STRING,
qty INT,
unit_price DECIMAL(10,2)
) USING DELTA;

# %%
# %sql
INSERT INTO orders_managed VALUES
  (1,  'A101', 'iPhone Charger',       'Electronics', 2, 19.99),
  (2,  'A102', 'Bluetooth Headphones', 'Electronics', 1, 49.50),
  (3,  'A103', 'HDMI Cable',           'Electronics', 3, 5.99);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE DETAIL orders_managed;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
DESCRIBE FORMATTED orders_managed;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
DESCRIBE EXTENDED orders_managed;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
create catalog deltalake_catalog
managed location 'abfss://unitycatalog@ttmystorageaccount001.dfs.core.windows.net/catalog'

# %%
# %sql
use catalog deltalake_catalog;

# %%
# %sql
SELECT current_catalog();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_catalog()</th></tr></thead><tbody><tr><td>deltalake_catalog</td></tr></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE TABLE orders_managed (
order_id BIGINT,
sku STRING,
product_name STRING,
product_category STRING,
qty INT,
unit_price DECIMAL(10,2)
) USING DELTA;

# %%
# %sql
INSERT INTO orders_managed VALUES
  (1,  'A101', 'iPhone Charger',       'Electronics', 2, 19.99),
  (2,  'A102', 'Bluetooth Headphones', 'Electronics', 1, 49.50),
  (3,  'A103', 'HDMI Cable',           'Electronics', 3, 5.99);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE DETAIL deltalake_catalog.default.orders_managed;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(dbutils.fs.ls("abfss://unitycatalog@ttmystorageaccount001.dfs.core.windows.net/catalog/__unitystorage"))
# Out:
# ---------------------------------------------------------------------------
# ExecutionError                            Traceback (most recent call last)
# File <command-4563688391483952>, line 1
# ----> 1 display(dbutils.fs.ls("abfss://unitycatalog@ttmystorageaccount001.dfs.core.windows.net/catalog/__unitystorage"))
#
# File /databricks/python_shell/lib/dbruntime/remotefshandler/RemoteFsHandler.py:52, in prettify_exception_message.<locals>.f_with_exception_handling(*args, **kwargs)
#      49 class ExecutionError(Exception):
#      50     pass
# ---> 52 raise ExecutionError(str(e)) from None
#
# ExecutionError: [RequestId=eaf2826e-3fcc-4f4d-89a0-46475a7f14aa ErrorClass=INVALID_PARAMETER_VALUE.LOCATION_OVERLAP] Input path url 'abfss://unitycatalog@ttmystorageaccount001.dfs.core.windows.net/catalog/__unitystorage' overlaps with managed storage within 'ListFiles' call. .
#
# JVM stacktrace:
# com.databricks.sql.managedcatalog.UnityCatalogServiceException
# ...

# %%
log_file_path = "https://ttmystorageaccount001.blob.core.windows.net/unitycatalog/catalog/__unitystorage/catalogs/758280e5-e8ae-48b0-840c-9f10d52cc821/tables/2c9e6121-c089-4416-8602-38aeb7f7339c/_delta_log/00000000000000000001.json"

df_log = spark.read.json(log_file_path)

display(df_log)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperationException             Traceback (most recent call last)
# File <command-4563688391483953>, line 5
#       1 log_file_path = "https://ttmystorageaccount001.blob.core.windows.net/unitycatalog/catalog/__unitystorage/catalogs/758280e5-e8ae-48b0-840c-9f10d52cc821/tables/2c9e6121-c089-4416-8602-38aeb7f7339c/_delta_log/00000000000000000001.json"
#       3 df_log = spark.read.json(log_file_path)
# ----> 5 display(df_log)
#
# File /databricks/python_shell/lib/dbruntime/display.py:133, in Display.display(self, input, *args, **kwargs)
#     131     pass
#     132 elif self._cf_helper is not None and isinstance(input, ConnectDataFrame):
# --> 133     self.display_connect_table(input, **kwargs)
#     134 elif isinstance(input, ConnectDataFrame):
#     135     if input.isStreaming:
#
# File /databricks/python_shell/lib/dbruntime/display.py:93, in Display.display_connect_table(self, df, **kwargs)
# ...

# %%
# %sql
drop table deltalake_catalog.default.orders_managed;

# %%
from delta.tables import DeltaTable

DeltaTable.createIfNotExists(spark) \
.tableName("orders_managed_new")  \
.addColumn("order_id", "BIGINT") \
.addColumn("sku", "STRING") \
.addColumn("product_name", "STRING") \
.addColumn("product_category", "STRING" ,  comment = "this is the product category") \
.addColumn("qty", "INT") \
.addColumn("unit_price", "DECIMAL(10,2)") \
.execute()

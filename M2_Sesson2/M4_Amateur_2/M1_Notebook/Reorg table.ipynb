# %%
# %sql
use catalog deltalake_catalog;

# %%
# %sql
DROP TABLE IF EXISTS orders_ext_01;

CREATE OR REPLACE TABLE orders_ext_01 (
order_id BIGINT,
sku STRING,
product_name STRING,
product_category STRING,
qty INT,
unit_price DECIMAL(10,2)
) 
TBLPROPERTIES (
  delta.autoOptimize.optimizeWrite = false,
  delta.autoOptimize.autoCompact = false
)
LOCATION 'abfss://externaldata@ttmystorageaccount001.dfs.core.windows.net/orders'

# %%
# %sql
INSERT INTO orders_ext_01 VALUES
  (1, 'SKU-1001', 'Wireless Mouse', 'Electronics', 2, 799.00),
  (2, 'SKU-2001', 'Yoga Mat', 'Fitness', 1, 1199.00),
  (3, 'SKU-3001', 'Notebook A5', 'Stationery', 5, 49.50),
  (4, 'SKU-4001', 'Coffee Mug', 'Kitchen', 3, 299.00),
  (5, 'SKU-5001', 'LED Bulb', 'Electronics', 4, 149.99);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

# %%
# %sql
delete from orders_ext_01 where order_id = 4
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %%
# %sql
describe history orders_ext_01
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>2</td><td>2025-09-10T06:03:58Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>DELETE</td><td>Map(predicate -> ["(order_id#442L = 4)"])</td><td>null</td><td>List(2134047553962487)</td><td>0904-192152-enrjcmmz</td><td>1</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 6260, numDeletionVectorsUpdated -> 0, numDeletedRows -> 1, scanTimeMs -> 4661, numAddedFiles -> 0, numAddedBytes -> 0, rewriteTimeMs -> 1587)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.12</td></tr><tr><td>1</td><td>2025-09-10T06:03:25Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(2134047553962487)</td><td>0904-192152-enrjcmmz</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 5, numOutputBytes -> 2200)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.12</td></tr><tr><td>0</td><td>2025-09-10T06:03:07Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>CREATE OR REPLACE TABLE</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> false, properties -> {"delta.autoOptimize.autoCompact":"false","delta.autoOptimize.optimizeWrite":"false","delta.enableDeletionVectors":"true"}, statsOnLoad -> false)</td><td>null</td><td>List(2134047553962487)</td><td>0904-192152-enrjcmmz</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.12</td></tr></tbody></table></div>

# %%
# %sql
REORG TABLE orders_ext_01 APPLY (PURGE)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>abfss://externaldata@ttmystorageaccount001.dfs.core.windows.net/orders</td><td>List(0, 0, List(null, null, 0.0, 0, 0), List(null, null, 0.0, 0, 0), 0, null, null, 0, 0, 1, 0, true, 0, 0, 1757484561645, 1757484564712, 4, 0, null, List(0, 0), null, 6, 6, 0, 0, null)</td></tr></tbody></table></div>

# %%
# %sql
describe history orders_ext_01
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>3</td><td>2025-09-10T06:05:49Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>REORG</td><td>Map(predicate -> [], batchId -> 0, applyPurge -> true)</td><td>null</td><td>List(2134047553962487)</td><td>0904-192152-enrjcmmz</td><td>2</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 1, numRemovedBytes -> 2200, p25FileSize -> 2139, numDeletionVectorsRemoved -> 1, minFileSize -> 2139, numAddedFiles -> 1, maxFileSize -> 2139, p75FileSize -> 2139, p50FileSize -> 2139, numAddedBytes -> 2139)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.12</td></tr><tr><td>2</td><td>2025-09-10T06:03:58Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>DELETE</td><td>Map(predicate -> ["(order_id#442L = 4)"])</td><td>null</td><td>List(2134047553962487)</td><td>0904-192152-enrjcmmz</td><td>1</td><td>WriteSerializable</td><td>false</td><td>Map(numRemovedFiles -> 0, numRemovedBytes -> 0, numCopiedRows -> 0, numDeletionVectorsAdded -> 1, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 6260, numDeletionVectorsUpdated -> 0, numDeletedRows -> 1, scanTimeMs -> 4661, numAddedFiles -> 0, numAddedBytes -> 0, rewriteTimeMs -> 1587)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.12</td></tr><tr><td>1</td><td>2025-09-10T06:03:25Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>WRITE</td><td>Map(mode -> Append, statsOnLoad -> false, partitionBy -> [])</td><td>null</td><td>List(2134047553962487)</td><td>0904-192152-enrjcmmz</td><td>0</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputRows -> 5, numOutputBytes -> 2200)</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.12</td></tr><tr><td>0</td><td>2025-09-10T06:03:07Z</td><td>147711536460494</td><td>sumit.trendytech03@outlook.com</td><td>CREATE OR REPLACE TABLE</td><td>Map(partitionBy -> [], clusterBy -> [], description -> null, isManaged -> false, properties -> {"delta.autoOptimize.autoCompact":"false","delta.autoOptimize.optimizeWrite":"false","delta.enableDeletionVectors":"true"}, statsOnLoad -> false)</td><td>null</td><td>List(2134047553962487)</td><td>0904-192152-enrjcmmz</td><td>null</td><td>WriteSerializable</td><td>true</td><td>Map()</td><td>null</td><td>Databricks-Runtime/16.4.x-scala2.12</td></tr></tbody></table></div>

# %%
# %sql
create volume if not exists my_demo_volume

# %%
data = [(1, "Alice"), (2, "Bob"), (3, "Charlie")]
df = spark.createDataFrame(data, ["id", "name"])
display(df)

# %%
volume_path = "/Volumes/training_centralindia_dbws_3659108987659416/default/my_demo_volume/dv_demo"
df.write.format("delta").mode("overwrite").save(volume_path)

# %%
# %sql
SELECT * FROM delta.`/Volumes/training_centralindia_dbws_3659108987659416/default/my_demo_volume/dv_demo`;

# %%
new_data = [(4, "David"), (5, "Eve"), (6, "Frank")]
new_df = spark.createDataFrame(new_data, ["id", "name"])

# %%
new_df.write.format("delta").mode("append").save(volume_path)

# %%
# %sql
SELECT * FROM delta.`/Volumes/training_centralindia_dbws_3659108987659416/default/my_demo_volume/dv_demo`;

# %%
log_file_path = "/Volumes/training_centralindia_dbws_3659108987659416/default/my_demo_volume/dv_demo/_delta_log/00000000000000000002.json"

# Read the JSON as a DataFrame
df_log = spark.read.json(log_file_path)

# Show content
display(df_log)

# %%
# %sql
-- Delete one row (creates Deletion Vector)
DELETE FROM delta.`/Volumes/training_centralindia_dbws_3659108987659416/default/my_demo_volume/dv_demo WHERE ID = 4`;

# %%
# %sql
describe history delta.`/Volumes/training_centralindia_dbws_3659108987659416/default/my_demo_volume/dv_demo`;

# %%
# %sql
describe detail delta.`/Volumes/training_centralindia_dbws_3659108987659416/default/my_demo_volume/dv_demo`;

# %%
# %sql
RESTORE TABLE delta.`/Volumes/training_centralindia_dbws_3659108987659416/default/my_demo_volume/dv_demo` TO VERSION AS OF 2;

# %%
# %sql
RESTORE TABLE delta./Volumes/training_centralindia_dbws_3659108987659416/default/my_demo_volume/dv_demo` TO VERSION AS OF 3;

# %%
# %sql
REORG TABLE delta.`/Volumes/training_centralindia_dbws_3659108987659416/default/my_demo_volume/dv_demo` APPLY (PURGE)

# %%
# %sql
VACUUM delta.`/Volumes/training_centralindia_dbws_3659108987659416/default/my_demo_volume/dv_demo` RETAIN 0 HOURS;

# %%
# %sql
SET spark.databricks.delta.retentionDurationCheck.enabled = false;

# %%
# %sql
ALTER TABLE delta.`/Volumes/training_centralindia_dbws_3659108987659416/default/my_demo_volume/dv_demo` SET TBLPROPERTIES ('delta.deletedFileRetentionDuration'='interval 0 hours')

# %%
# %sql
VACUUM delta.`/Volumes/training_centralindia_dbws_3659108987659416/default/my_demo_volume/dv_demo` DRY RUN;

# %%
# %sql
VACUUM delta.`/Volumes/training_centralindia_dbws_3659108987659416/default/my_demo_volume/dv_demo`;

# %%
# %sql
VACUUM delta.`/Volumes/training_centralindia_dbws_3659108987659416/default/my_demo_volume/dv_demo`;

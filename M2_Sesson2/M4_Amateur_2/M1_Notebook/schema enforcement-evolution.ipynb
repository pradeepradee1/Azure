# %%
# %sql
use catalog deltalake_catalog;

# %%
# %sql
-- current table info & rows
DESCRIBE DETAIL DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1`;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT * FROM DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1` ORDER BY order_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>sku</th><th>product_name</th><th>product_category</th><th>qty</th><th>unit_price</th></tr></thead><tbody><tr><td>1</td><td>SKU-1001</td><td>Wireless Mouse</td><td>Electronics</td><td>2</td><td>799.00</td></tr><tr><td>2</td><td>SKU-2001</td><td>Yoga Mat - snapshot</td><td>Fitness</td><td>3</td><td>1049.00</td></tr><tr><td>10</td><td>SKU-1009</td><td>Bad Qty Example</td><td>Misc</td><td>2</td><td>99.99</td></tr><tr><td>11</td><td>SKU-1009</td><td>Bad Qty Example</td><td>Misc</td><td>5</td><td>99.99</td></tr></tbody></table></div>

# %%
# %sql
describe history DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
DESCRIBE FORMATTED DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
CREATE OR REPLACE TEMP VIEW bad_rows AS
SELECT * FROM VALUES
  (10, 'SKU-1009', 'Bad Qty Example', 'Misc', 'two', 99.99)
AS t(order_id, sku, product_name, product_category, qty, unit_price);

INSERT INTO DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1`
SELECT * FROM bad_rows;
# Out:
# ---------------------------------------------------------------------------
# NumberFormatException                     Traceback (most recent call last)
# File <command-6438251473264072>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', "CREATE OR REPLACE TEMP VIEW bad_rows AS\nSELECT * FROM VALUES\n  (10, 'SKU-1009', 'Bad Qty Example', 'Misc', 'two', 99.99)\nAS t(order_id, sku, product_name, product_category, qty, unit_price);\n\nINSERT INTO DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1`\nSELECT * FROM bad_rows;\n")
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2543, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2541 with self.builtin_trap:
#    2542     args = (magic_arg_s, cell)
# -> 2543     result = fn(*args, **kwargs)
#    2545 # The code below prevents the output from being displayed
#    2546 # when using magics with decorator @output_can_be_silenced
# ...

# %%
# %sql
CREATE OR REPLACE TEMP VIEW bad_rows AS
SELECT * FROM VALUES
  (10, 'SKU-1009', 'Bad Qty Example', 'Misc', "2" , 99.99)
AS t(order_id, sku, product_name, product_category, qty, unit_price);

INSERT INTO DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1`
SELECT * FROM bad_rows;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
describe formatted DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
CREATE OR REPLACE TEMP VIEW bad_rows AS
SELECT * FROM VALUES
  (11, 'SKU-1009', 'Bad Qty Example', 'Misc', 5.2 , 99.99)
AS t(order_id, sku, product_name, product_category, qty, unit_price);

INSERT INTO DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1`
SELECT * FROM bad_rows;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE TEMP VIEW extra_col_src AS
SELECT * FROM VALUES
  (12, 'SKU-1010', 'Extra Col Item', 'Misc', 1, 49.00, 5.0)
AS t(order_id, sku, product_name, product_category, qty, unit_price, discount);

INSERT INTO DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1` SELECT * FROM extra_col_src
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-6438251473264076>, line 1
# ----> 1 get_ipython().run_cell_magic('sql', '', "CREATE OR REPLACE TEMP VIEW extra_col_src AS\nSELECT * FROM VALUES\n  (12, 'SKU-1010', 'Extra Col Item', 'Misc', 1, 49.00, 5.0)\nAS t(order_id, sku, product_name, product_category, qty, unit_price, discount);\n\nINSERT INTO DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1` SELECT * FROM extra_col_src\n")
#
# File /databricks/python/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2543, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2541 with self.builtin_trap:
#    2542     args = (magic_arg_s, cell)
# -> 2543     result = fn(*args, **kwargs)
#    2545 # The code below prevents the output from being displayed
#    2546 # when using magics with decorator @output_can_be_silenced
# ...

# %%
# %sql
-- add a new column 'discount' (DOUBLE) to the target table
ALTER TABLE DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1`
ADD COLUMNS (discount DOUBLE);


-- Now insert the row with the extra column (works because we added the column)
INSERT INTO DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1`
SELECT order_id, sku, product_name, product_category, qty, unit_price, discount
FROM extra_col_src;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1` ORDER BY order_id;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
CREATE OR REPLACE TEMP VIEW incoming_with_newcol AS
SELECT * FROM VALUES
  (13, 'SKU-1011', 'Auto Evolve Item', 'Promo', 2, 199.00, 5, 'PROMO10')
AS t(order_id, sku, product_name, product_category, qty, unit_price, discount,promotion_code);

# %%
# %sql
MERGE WITH SCHEMA EVOLUTION INTO DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1` AS target
USING incoming_with_newcol AS src
  ON target.order_id = src.order_id
WHEN MATCHED THEN UPDATE SET *
WHEN NOT MATCHED THEN INSERT *;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>0</td><td>0</td><td>1</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from decimal import Decimal
from pyspark.sql.types import StructType, StructField, LongType, StringType, IntegerType, DecimalType

# Sample new rows that include a new column 'promotion_code'
rows = [
    (5001, 'SKU-5001', 'Promo Item A', 'Promo', 2, 'PROMO10'),
    (5002, 'SKU-5002', 'Promo Item B', 'Promo', 1, 'PROMO20')
]

# Schema includes the new column
schema = StructType([
    StructField("order_id", LongType(), False),
    StructField("sku", StringType(), True),
    StructField("product_name", StringType(), True),
    StructField("product_category", StringType(), True),
    StructField("qty", IntegerType(), True),
    StructField("promo", StringType(), True) 
])

# Create DataFrame
df = spark.createDataFrame(rows, schema=schema)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>sku</th><th>product_name</th><th>product_category</th><th>qty</th><th>promo</th></tr></thead><tbody><tr><td>5001</td><td>SKU-5001</td><td>Promo Item A</td><td>Promo</td><td>2</td><td>PROMO10</td></tr><tr><td>5002</td><td>SKU-5002</td><td>Promo Item B</td><td>Promo</td><td>1</td><td>PROMO20</td></tr></tbody></table></div>

# %%
df.write \
  .format("delta") \
  .mode("append") \
  .option("mergeSchema", "true") \
  .save("/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1")

# %%
from decimal import Decimal
from pyspark.sql.types import StructType, StructField, LongType, StringType, IntegerType, DecimalType

# Sample new rows that include a new column 'promotion_code'
rows = [
    (5003, 'SKU-5001', 'Promo Item A', 'Promo', 2, 'PROMO10'),
    (5004, 'SKU-5002', 'Promo Item B', 'Promo', 1, 'PROMO20')
]

# Schema includes the new column
schema = StructType([
    StructField("order_id", LongType(), False),
    StructField("sku", StringType(), True),
    StructField("product_name", StringType(), True),
    StructField("product_category", StringType(), True),
    StructField("qty", LongType(), True),
    StructField("promo", StringType(), True) 
])

# Create DataFrame
df = spark.createDataFrame(rows, schema=schema)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>sku</th><th>product_name</th><th>product_category</th><th>qty</th><th>promo</th></tr></thead><tbody><tr><td>5003</td><td>SKU-5001</td><td>Promo Item A</td><td>Promo</td><td>2</td><td>PROMO10</td></tr><tr><td>5004</td><td>SKU-5002</td><td>Promo Item B</td><td>Promo</td><td>1</td><td>PROMO20</td></tr></tbody></table></div>

# %%
df.printSchema()
# Out:
# root
#  |-- order_id: long (nullable = false)
#  |-- sku: string (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- product_category: string (nullable = true)
#  |-- qty: long (nullable = true)
#  |-- promo: string (nullable = true)

# %%
df.write \
  .format("delta") \
  .mode("append") \
  .option("mergeSchema", "true") \
  .save("/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1")

# %%
# %sql
alter table DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1` 
SET tblproperties ('delta.enableTypeWidening' = 'true')

# %%
# %sql
show tblproperties DELTA.`/Volumes/deltalake_catalog/default/delta_volume1/ordersdata1`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>value</th></tr></thead><tbody><tr><td>delta.enableDeletionVectors</td><td>true</td></tr><tr><td>delta.enableTypeWidening</td><td>true</td></tr><tr><td>delta.feature.appendOnly</td><td>supported</td></tr><tr><td>delta.feature.deletionVectors</td><td>supported</td></tr><tr><td>delta.feature.invariants</td><td>supported</td></tr><tr><td>delta.feature.typeWidening</td><td>supported</td></tr><tr><td>delta.minReaderVersion</td><td>3</td></tr><tr><td>delta.minWriterVersion</td><td>7</td></tr></tbody></table></div>

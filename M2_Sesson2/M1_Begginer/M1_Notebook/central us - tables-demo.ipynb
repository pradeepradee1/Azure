# %%
# %sql
SHOW EXTERNAL LOCATIONS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>url</th><th>comment</th></tr></thead><tbody><tr><td>adls_raw_storage_ext_loc</td><td>abfss://unitycatalog@databricksdemo101sa.dfs.core.windows.net/metastore</td><td>null</td></tr><tr><td>training_centralus_dbws</td><td>abfss://unity-catalog-storage@dbstoragexfwzyxicygk5a.dfs.core.windows.net/1458912397224799</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
SHOW GRANTS ON EXTERNAL LOCATION adls_raw_storage_ext_loc;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Principal</th><th>ActionType</th><th>ObjectType</th><th>ObjectKey</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
GRANT CREATE MANAGED STORAGE ON EXTERNAL LOCATION adls_raw_storage_ext_loc TO `sumit.trendytech02_outlook.com#EXT#@sumittrendytech02outlook.onmicrosoft.com`;
    
SHOW GRANTS ON EXTERNAL LOCATION adls_raw_storage_ext_loc;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Principal</th><th>ActionType</th><th>ObjectType</th><th>ObjectKey</th></tr></thead><tbody><tr><td>sumit.trendytech02_outlook.com#ext#@sumittrendytech02outlook.onmicrosoft.com</td><td>CREATE MANAGED STORAGE</td><td>EXTERNAL LOCATION</td><td>adls_raw_storage_ext_loc</td></tr></tbody></table></div>

# %%
# %sql
CREATE CATALOG sales_catalog;

# %%
# %sql
CREATE SCHEMA sales_catalog.retaildb;

# %%
# %sql
CREATE TABLE sales_catalog.retaildb.sales (
    sale_id INT,
    customer_name STRING,
    product STRING,
    quantity INT,
    amount DOUBLE
);

# %%
# %sql
INSERT INTO sales_catalog.retaildb.sales VALUES
(1, 'Alice', 'Laptop', 1, 1200.00),
(2, 'Bob', 'Tablet', 2, 800.00),
(3, 'Charlie', 'Phone', 1, 500.00);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE EXTENDED sales_catalog.retaildb.sales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>sale_id</td><td>int</td><td>null</td></tr><tr><td>customer_name</td><td>string</td><td>null</td></tr><tr><td>product</td><td>string</td><td>null</td></tr><tr><td>quantity</td><td>int</td><td>null</td></tr><tr><td>amount</td><td>double</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>quantity, sale_id, customer_name, amount, product</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>sales_catalog</td><td></td></tr><tr><td>Database</td><td>retaildb</td><td></td></tr><tr><td>Table</td><td>sales</td><td></td></tr><tr><td>Created Time</td><td>Thu Jul 31 11:34:44 UTC 2025</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Statistics</td><td>1505 bytes, 3 rows</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td>abfss://unitycatalog@databricksdemo101sa.dfs.core.windows.net/metastore/fb283bcb-30ce-43aa-89ef-a701a1d0ca40/tables/0ddbc52c-6957-4e70-97d7-724b3a1c6067</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>sumit.trendytech02@outlook.com</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_azure_centralus)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.enableDeletionVectors=true,delta.feature.appendOnly=supported,delta.feature.deletionVectors=supported,delta.feature.invariants=supported,delta.minReaderVersion=3,delta.minWriterVersion=7]</td><td></td></tr></tbody></table></div>

# %%
# %sql
DROP CATALOG IF EXISTS sales_catalog CASCADE;

# %%
# %sql
CREATE EXTERNAL LOCATION adls_raw_storage_catalog_ext_loc URL
'abfss://unitycatalog@databricksdemo101sa.dfs.core.windows.net/catalog'
WITH (CREDENTIAL adls_raw_storage_cred)
COMMENT 'external location catalog level for raw sales data in adls';

# %%
# %sql
CREATE CATALOG sales_catalog 
MANAGED LOCATION 
'abfss://unitycatalog@databricksdemo101sa.dfs.core.windows.net/catalog';

# %%
# %sql
CREATE SCHEMA sales_catalog.retaildb;

# %%
# %sql
CREATE TABLE sales_catalog.retaildb.sales (
    sale_id INT,
    customer_name STRING,
    product STRING,
    quantity INT,
    amount DOUBLE
);

# %%
# %sql
INSERT INTO sales_catalog.retaildb.sales VALUES
(1, 'Alice', 'Laptop', 1, 1200.00),
(2, 'Bob', 'Tablet', 2, 800.00),
(3, 'Charlie', 'Phone', 1, 500.00);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
DESCRIBE EXTENDED sales_catalog.retaildb.sales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>sale_id</td><td>int</td><td>null</td></tr><tr><td>customer_name</td><td>string</td><td>null</td></tr><tr><td>product</td><td>string</td><td>null</td></tr><tr><td>quantity</td><td>int</td><td>null</td></tr><tr><td>amount</td><td>double</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>quantity, sale_id, customer_name, amount, product</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>sales_catalog</td><td></td></tr><tr><td>Database</td><td>retaildb</td><td></td></tr><tr><td>Table</td><td>sales</td><td></td></tr><tr><td>Created Time</td><td>Thu Jul 31 11:44:24 UTC 2025</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Statistics</td><td>1505 bytes, 3 rows</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td>abfss://unitycatalog@databricksdemo101sa.dfs.core.windows.net/catalog/__unitystorage/catalogs/48e70997-5595-4677-ae13-4c814681c7af/tables/39b53d75-b219-4bbe-979a-5cfaae360128</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>sumit.trendytech02@outlook.com</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_azure_centralus)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.enableDeletionVectors=true,delta.feature.appendOnly=supported,delta.feature.deletionVectors=supported,delta.feature.invariants=supported,delta.minReaderVersion=3,delta.minWriterVersion=7]</td><td></td></tr></tbody></table></div>

# %%
# %sql
CREATE EXTERNAL LOCATION adls_raw_storage_schema_ext_loc URL
'abfss://unitycatalog@databricksdemo101sa.dfs.core.windows.net/schema'
WITH (CREDENTIAL adls_raw_storage_cred)
COMMENT 'external location schema level for raw sales data in adls'

# %%
# %sql
CREATE SCHEMA sales_catalog.retaildb1 
MANAGED LOCATION 
'abfss://unitycatalog@databricksdemo101sa.dfs.core.windows.net/schema';

# %%
# %sql
CREATE TABLE sales_catalog.retaildb1.sales (
    sale_id INT,
    customer_name STRING,
    product STRING,
    quantity INT,
    amount DOUBLE
);

# %%
# %sql
INSERT INTO sales_catalog.retaildb1.sales VALUES
(1, 'Alice', 'Laptop', 1, 1200.00),
(2, 'Bob', 'Tablet', 2, 800.00),
(3, 'Charlie', 'Phone', 1, 500.00);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
DROP TABLE sales_catalog.retaildb.sales;

# %%
# %sql
SHOW TABLES DROPPED IN sales_catalog.retaildb;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>catalogName</th><th>schemaName</th><th>tableName</th><th>tableId</th><th>tableType</th><th>deletedAt</th><th>createdAt</th><th>updatedAt</th><th>createdBy</th><th>owner</th><th>comment</th><th>collation</th></tr></thead><tbody><tr><td>sales_catalog</td><td>retaildb</td><td>sales</td><td>39b53d75-b219-4bbe-979a-5cfaae360128</td><td>managed</td><td>2025-07-31 AD at 12:06:33 UTC</td><td>2025-07-31 AD at 11:44:24 UTC</td><td>2025-07-31 AD at 12:06:33 UTC</td><td>sumit.trendytech02@outlook.com</td><td>sumit.trendytech02@outlook.com</td><td></td><td></td></tr></tbody></table></div>

# %%
# %sql
select * from sales_catalog.retaildb.sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sale_id</th><th>customer_name</th><th>product</th><th>quantity</th><th>amount</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>Laptop</td><td>1</td><td>1200.0</td></tr><tr><td>2</td><td>Bob</td><td>Tablet</td><td>2</td><td>800.0</td></tr><tr><td>3</td><td>Charlie</td><td>Phone</td><td>1</td><td>500.0</td></tr></tbody></table></div>

# %%
# %sql
UNDROP TABLE sales_catalog.retaildb.sales;

-- UNDROP TABLE WITH ID '39b53d75-b219-4bbe-979a-5cfaae360128'

# %%
# %sql
CREATE EXTERNAL LOCATION adls_storage_external_data_loc URL
'abfss://unitycatalog@databricksdemo101sa.dfs.core.windows.net/external'
WITH (CREDENTIAL adls_raw_storage_cred)
COMMENT 'external location for handling external data in adls';

# %%
# %sql
CREATE TABLE sales (
    sale_id INT,
    customer_name STRING,
    product STRING,
    quantity INT,
    amount DOUBLE
)
location 'abfss://unitycatalog@databricksdemo101sa.dfs.core.windows.net/external';

# %%
# %sql
desc extended sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>sale_id</td><td>int</td><td>null</td></tr><tr><td>customer_name</td><td>string</td><td>null</td></tr><tr><td>product</td><td>string</td><td>null</td></tr><tr><td>quantity</td><td>int</td><td>null</td></tr><tr><td>amount</td><td>double</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>training_centralus_dbws</td><td></td></tr><tr><td>Database</td><td>default</td><td></td></tr><tr><td>Table</td><td>sales</td><td></td></tr><tr><td>Created Time</td><td>Thu Jul 31 12:21:11 UTC 2025</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Location</td><td>abfss://unitycatalog@databricksdemo101sa.dfs.core.windows.net/external</td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>sumit.trendytech02@outlook.com</td><td></td></tr><tr><td>Table Properties</td><td>[delta.enableDeletionVectors=true,delta.feature.appendOnly=supported,delta.feature.deletionVectors=supported,delta.feature.invariants=supported,delta.minReaderVersion=3,delta.minWriterVersion=7]</td><td></td></tr></tbody></table></div>

# %%
# %sql
INSERT INTO sales VALUES
(1, 'Alice', 'Laptop', 1, 1200.00),
(2, 'Bob', 'Tablet', 2, 800.00),
(3, 'Charlie', 'Phone', 1, 500.00);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
select * from sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sale_id</th><th>customer_name</th><th>product</th><th>quantity</th><th>amount</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>Laptop</td><td>1</td><td>1200.0</td></tr><tr><td>2</td><td>Bob</td><td>Tablet</td><td>2</td><td>800.0</td></tr><tr><td>3</td><td>Charlie</td><td>Phone</td><td>1</td><td>500.0</td></tr></tbody></table></div>

# %%
# %sql
DROP TABLE IF EXISTS sales;

# %%
# %sql
CREATE EXTERNAL LOCATION adls_storage_external_sales_data_loc URL
'abfss://unitycatalog@databricksdemo101sa.dfs.core.windows.net/external_1/sales'
WITH (CREDENTIAL adls_raw_storage_cred)
COMMENT 'external location for handling external sales data in adls'

# %%
# %sql
CREATE TABLE sales_ext (
    sale_id INT,
    customer_name STRING,
    product STRING,
    quantity INT,
    amount DOUBLE
)
USING CSV
location 'abfss://unitycatalog@databricksdemo101sa.dfs.core.windows.net/external_1/sales';

# %%
# %sql
select * from sales_ext;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sale_id</th><th>customer_name</th><th>product</th><th>quantity</th><th>amount</th></tr></thead><tbody><tr><td>1</td><td>Amit Verma</td><td>Laptop</td><td>1</td><td>55000.0</td></tr><tr><td>2</td><td>Neha Sharma</td><td>Smartphone</td><td>2</td><td>32000.0</td></tr><tr><td>3</td><td>Rahul Mehta</td><td>Headphones</td><td>3</td><td>4500.0</td></tr><tr><td>4</td><td>Sneha Iyer</td><td>Smartwatch</td><td>1</td><td>8000.0</td></tr><tr><td>5</td><td>Vikram Singh</td><td>Monitor</td><td>2</td><td>24000.0</td></tr><tr><td>6</td><td>Pooja Nair</td><td>Keyboard</td><td>4</td><td>3200.0</td></tr><tr><td>7</td><td>Ankit Rao</td><td>Tablet</td><td>1</td><td>18000.0</td></tr><tr><td>8</td><td>Meera Joshi</td><td>Laptop</td><td>2</td><td>105000.0</td></tr><tr><td>9</td><td>Kunal Kapoor</td><td>Mouse</td><td>5</td><td>2500.0</td></tr><tr><td>10</td><td>Divya Rathi</td><td>Printer</td><td>1</td><td>12500.0</td></tr></tbody></table></div>

# %%
# %sql
REFRESH TABLE training_centralus_dbws.default.sales_ext;

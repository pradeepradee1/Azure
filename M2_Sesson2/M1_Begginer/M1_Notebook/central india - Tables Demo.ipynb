# %% [markdown]
# ### how to check the current metastore

# %%
# %sql
SELECT current_metastore();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_metastore()</th></tr></thead><tbody><tr><td>azure:centralindia:50c22130-cb98-4662-8027-030a3c62b67a</td></tr></tbody></table></div>

# %%
# %sql
SELECT current_catalog();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_catalog()</th></tr></thead><tbody><tr><td>training_centralindia_dbws</td></tr></tbody></table></div>

# %%
# %sql
SELECT current_database();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_schema()</th></tr></thead><tbody><tr><td>default</td></tr></tbody></table></div>

# %%
# %sql
SHOW CATALOGS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>catalog</th></tr></thead><tbody><tr><td>hive_metastore</td></tr><tr><td>samples</td></tr><tr><td>system</td></tr><tr><td>training_centralindia_dbws</td></tr></tbody></table></div>

# %%
# %sql
SHOW SCHEMAS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>default</td></tr><tr><td>information_schema</td></tr></tbody></table></div>

# %%
# %sql
USE CATALOG samples;

# %%
# %sql
SHOW SCHEMAS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>accuweather</td></tr><tr><td>bakehouse</td></tr><tr><td>healthverity</td></tr><tr><td>information_schema</td></tr><tr><td>nyctaxi</td></tr><tr><td>tpcds_sf1</td></tr><tr><td>tpcds_sf1000</td></tr><tr><td>tpch</td></tr></tbody></table></div>

# %%
# %sql
USE CATALOG training_centralindia_dbws;

# %%
# %sql
CREATE TABLE IF NOT EXISTS training_centralindia_dbws.default.students (
    id INT,
    name STRING,
    score FLOAT
);

# %%
# %sql
INSERT INTO training_centralindia_dbws.default.students (id, name, score) VALUES
(1, 'Alice', 85.5),
(2, 'Bob', 90.0),
(3, 'Charlie', 78.5);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
select * from training_centralindia_dbws.default.students;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>score</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>85.5</td></tr><tr><td>2</td><td>Bob</td><td>90.0</td></tr><tr><td>3</td><td>Charlie</td><td>78.5</td></tr></tbody></table></div>

# %%
# %sql
DESC EXTENDED training_centralindia_dbws.default.students;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
CREATE TABLE IF NOT EXISTS hive_metastore.default.students (
    id INT,
    name STRING,
    score FLOAT
);

# %%
# %sql
INSERT INTO hive_metastore.default.students (id, name, score) VALUES
(1, 'Alice', 85.5),
(2, 'Bob', 90.0),
(3, 'Charlie', 78.5);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
DESC EXTENDED hive_metastore.default.students;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
dbutils.fs.ls("dbfs:/user/hive/warehouse/students")
# Out:
# [FileInfo(path='dbfs:/user/hive/warehouse/students/_delta_log/', name='_delta_log/', size=0, modificationTime=1753883674000),
#  FileInfo(path='dbfs:/user/hive/warehouse/students/part-00000-823f6778-5fdc-409c-838d-64982ad123af-c000.snappy.parquet', name='part-00000-823f6778-5fdc-409c-838d-64982ad123af-c000.snappy.parquet', size=1116, modificationTime=1753883694000)]

# %%
# %sql
create schema training_centralindia_dbws.my_schema;

# %%
# %sql
CREATE TABLE IF NOT EXISTS training_centralindia_dbws.my_schema.students (
    id INT,
    name STRING,
    score FLOAT
);

# %%
# %sql
INSERT INTO training_centralindia_dbws.my_schema.students (id, name, score) VALUES
(1, 'Alice', 85.5),
(2, 'Bob', 90.0),
(3, 'Charlie', 78.5);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
create catalog my_catalog1
managed location 'abfss://unitycatalog@databricksdemo101sa.dfs.core.windows.net/catalog';

# %%
# %sql
use catalog my_catalog1;

# %%
# %sql
create schema my_schema1;

# %%
# %sql
CREATE TABLE IF NOT EXISTS my_schema1.students1 (
    id INT,
    name STRING,
    score FLOAT
);

# %%
# %sql
INSERT INTO my_schema1.students1 (id, name, score) VALUES
(1, 'Alice', 85.5),
(2, 'Bob', 90.0),
(3, 'Charlie', 78.5);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>
